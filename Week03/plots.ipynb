# %%
import ex1, ex3
# Ex 1.10
ex1.chart_progression()
# Out:
# {'0-10': 4, '11-20': 2, '21-30': 3, '31-40': 1, '41-50': 0, '51-60': 0, '61-70': 0, '71-80': 0, '81-90': 0, '91-100': 0}
# {'0-10': 4, '11-20': 2, '21-30': 3, '31-40': 1, '41-50': 0, '51-60': 0, '61-70': 0, '71-80': 0, '81-90': 0, '91-100': 0}

# %%
# Ex 3.1
student_data = ex1.read_student_data()
ex3.show_pie_chart(student_data)

# %%
# Ex 3.2
ex3.bar_chart_courses(student_data)

# %%
# Ex 3.3
ex3.course_chart_gender(student_data)
